# %%
from numpy.random import seed
seed(1)

import numpy as np
import pandas as pd

# %%
import tensorflow
tensorflow.keras.__version__
# Out:
# '2.2.4-tf'

# %%
data = pd.read_csv('../datasets/spotify_data.csv')
data.head()
# Out:
#                       track             artist  \
# 0                 Lucky Man  Montgomery Gentry
# 1            On The Hotline       Pretty Ricky
# 2        Clouds Of Dementia         Candlemass
# 3  Heavy Metal, Raise Hell!      Zwartketterij
# 4           I Got A Feelin'   Billy Currington
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:4GiXBCUF7H6YfNQsnBRIzl         0.578   0.471    4    -7.270
# 1  spotify:track:1zyqZONW985Cs4osz9wlsu         0.704   0.854   10    -5.477
# 2  spotify:track:6cHZf7RbxXCKwEkgAZT4mY         0.162   0.836    9    -3.009
# 3  spotify:track:2IjBPp2vMeX7LggzRN3iSX         0.188   0.994    4    -3.745
# 4  spotify:track:1tF370eYXUcWwkIvaq3IGz         0.630   0.764    2    -4.353
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0289      0.368000           0.00000     0.159    0.532
# 1     0       0.1830      0.018500           0.00000     0.148    0.688
# 2     1       0.0473      0.000111           0.00457     0.174    0.300
# 3     1       0.1660      0.000007           0.07840     0.192    0.333
# 4     1       0.0275      0.363000           0.00000     0.125    0.631
#
#      tempo  duration_ms  time_signature  chorus_hit  sections  target  decade
# 0  133.061       196707               4    30.88059        13       1    2000
# 1   92.988       242587               4    41.51106        10       1    2000
# 2   86.964       338893               4    65.32887        13       0    2000
# 3  148.440       255667               4    58.59528         9       0    2000
# 4  112.098       193760               4    22.62384        10       1    2000

# %%
data_10s = data[data["decade"] == 2010]
data_10s.head()
# Out:
#                                     track                          artist  \
# 5872                          Wild Things                    Alessia Cara
# 5873                            Surfboard                       Esquivel!
# 5874                         Love Someone                    Lukas Graham
# 5875  Music To My Ears (feat. Tory Lanez)                   Keys N Krates
# 5876        Juju On That Beat (TZ Anthem)  Zay Hilfigerrr & Zayion McCall
#
#                                        uri  danceability  energy  key  \
# 5872  spotify:track:2ZyuwVvV6Z3XJaXIFbspeE         0.741   0.626    1
# 5873  spotify:track:61APOtq25SCMuK0V5w2Kgp         0.447   0.247    5
# 5874  spotify:track:2JqnpexlO9dmvjUMCaLCLJ         0.550   0.415    9
# 5875  spotify:track:0cjfLhk8WJ3etPTCseKXtk         0.502   0.648    0
# 5876  spotify:track:1lItf5ZXJc1by9SbPeljFd         0.807   0.887    1
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 5872    -4.826     0       0.0886       0.02000             0.000    0.0828
# 5873   -14.661     0       0.0346       0.87100             0.814    0.0946
# 5874    -6.557     0       0.0520       0.16100             0.000    0.1080
# 5875    -5.698     0       0.0527       0.00513             0.000    0.2040
# 5876    -3.892     1       0.2750       0.00381             0.000    0.3910
#
#       valence    tempo  duration_ms  time_signature  chorus_hit  sections  \
# 5872    0.706  108.029       188493               4    41.18681        10
# 5873    0.250  155.489       176880               3    33.18083         9
# 5874    0.274  172.065       205463               4    44.89147         9
# 5875    0.291   91.837       193043               4    29.52521         7
# 5876    0.780  160.517       144244               4    24.99199         8
#
#       target  decade
# 5872       1    2010
# 5873       0    2010
# 5874       1    2010
# 5875       0    2010
# 5876       1    2010

# %%
X = data.drop(['track', 'artist', 'uri', 'target', 'decade', 'chorus_hit', 'sections'], axis=1)
y = data["target"]
print(X.shape, y.shape)
# Out:
# (41106, 13) (41106,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=1)

# %%
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Create model and add layers
model = Sequential()
model.add(Dense(units=30, activation='relu', input_dim=13))
model.add(Dense(units=15, activation='relu'))
model.add(Dense(units=2, activation='softmax'))

# %%
# Compile and fit the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 30)                420
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                465
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 32
# =================================================================
# Total params: 917
# Trainable params: 917
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(
    X_train_scaled,
    y_train,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 30829 samples
# Epoch 1/100
# 30829/30829 - 1s - loss: 0.5599 - accuracy: 0.7023
# Epoch 2/100
# 30829/30829 - 1s - loss: 0.5170 - accuracy: 0.7398
# Epoch 3/100
# 30829/30829 - 1s - loss: 0.5074 - accuracy: 0.7487
# Epoch 4/100
# 30829/30829 - 1s - loss: 0.5039 - accuracy: 0.7493
# Epoch 5/100
# 30829/30829 - 1s - loss: 0.5019 - accuracy: 0.7504
# Epoch 6/100
# 30829/30829 - 1s - loss: 0.5007 - accuracy: 0.7504
# Epoch 7/100
# 30829/30829 - 1s - loss: 0.4987 - accuracy: 0.7525
# Epoch 8/100
# 30829/30829 - 1s - loss: 0.4972 - accuracy: 0.7546
# Epoch 9/100
# 30829/30829 - 1s - loss: 0.4944 - accuracy: 0.7573
# Epoch 10/100
# 30829/30829 - 1s - loss: 0.4929 - accuracy: 0.7595
# Epoch 11/100
# 30829/30829 - 1s - loss: 0.4907 - accuracy: 0.7608
# Epoch 12/100
# 30829/30829 - 1s - loss: 0.4897 - accuracy: 0.7610
# Epoch 13/100
# 30829/30829 - 1s - loss: 0.4878 - accuracy: 0.7618
# Epoch 14/100
# 30829/30829 - 1s - loss: 0.4865 - accuracy: 0.7635
# Epoch 15/100
# 30829/30829 - 1s - loss: 0.4860 - accuracy: 0.7623
# Epoch 16/100
# 30829/30829 - 1s - loss: 0.4845 - accuracy: 0.7643
# Epoch 17/100
# 30829/30829 - 1s - loss: 0.4844 - accuracy: 0.7634
# Epoch 18/100
# 30829/30829 - 1s - loss: 0.4835 - accuracy: 0.7654
# Epoch 19/100
# 30829/30829 - 1s - loss: 0.4823 - accuracy: 0.7645
# Epoch 20/100
# 30829/30829 - 1s - loss: 0.4824 - accuracy: 0.7639
# Epoch 21/100
# 30829/30829 - 1s - loss: 0.4808 - accuracy: 0.7665
# Epoch 22/100
# 30829/30829 - 1s - loss: 0.4803 - accuracy: 0.7671
# Epoch 23/100
# 30829/30829 - 1s - loss: 0.4800 - accuracy: 0.7665
# Epoch 24/100
# 30829/30829 - 1s - loss: 0.4796 - accuracy: 0.7681
# Epoch 25/100
# 30829/30829 - 1s - loss: 0.4786 - accuracy: 0.7686
# Epoch 26/100
# 30829/30829 - 1s - loss: 0.4778 - accuracy: 0.7674
# Epoch 27/100
# 30829/30829 - 1s - loss: 0.4786 - accuracy: 0.7684
# Epoch 28/100
# 30829/30829 - 1s - loss: 0.4768 - accuracy: 0.7692
# Epoch 29/100
# 30829/30829 - 1s - loss: 0.4761 - accuracy: 0.7696
# Epoch 30/100
# 30829/30829 - 1s - loss: 0.4767 - accuracy: 0.7694
# Epoch 31/100
# 30829/30829 - 1s - loss: 0.4755 - accuracy: 0.7695
# Epoch 32/100
# 30829/30829 - 1s - loss: 0.4744 - accuracy: 0.7699
# Epoch 33/100
# 30829/30829 - 1s - loss: 0.4743 - accuracy: 0.7696
# Epoch 34/100
# 30829/30829 - 1s - loss: 0.4738 - accuracy: 0.7702
# Epoch 35/100
# 30829/30829 - 1s - loss: 0.4722 - accuracy: 0.7734
# Epoch 36/100
# 30829/30829 - 1s - loss: 0.4723 - accuracy: 0.7716
# Epoch 37/100
# 30829/30829 - 1s - loss: 0.4725 - accuracy: 0.7733
# Epoch 38/100
# 30829/30829 - 1s - loss: 0.4725 - accuracy: 0.7733
# Epoch 39/100
# 30829/30829 - 1s - loss: 0.4721 - accuracy: 0.7722
# Epoch 40/100
# 30829/30829 - 1s - loss: 0.4708 - accuracy: 0.7739
# Epoch 41/100
# 30829/30829 - 1s - loss: 0.4712 - accuracy: 0.7737
# Epoch 42/100
# 30829/30829 - 1s - loss: 0.4703 - accuracy: 0.7733
# Epoch 43/100
# 30829/30829 - 1s - loss: 0.4700 - accuracy: 0.7758
# Epoch 44/100
# 30829/30829 - 1s - loss: 0.4695 - accuracy: 0.7743
# Epoch 45/100
# 30829/30829 - 1s - loss: 0.4697 - accuracy: 0.7755
# Epoch 46/100
# 30829/30829 - 1s - loss: 0.4682 - accuracy: 0.7758
# Epoch 47/100
# 30829/30829 - 1s - loss: 0.4686 - accuracy: 0.7746
# Epoch 48/100
# 30829/30829 - 1s - loss: 0.4677 - accuracy: 0.7753
# Epoch 49/100
# 30829/30829 - 1s - loss: 0.4680 - accuracy: 0.7751
# Epoch 50/100
# 30829/30829 - 1s - loss: 0.4683 - accuracy: 0.7757
# Epoch 51/100
# 30829/30829 - 1s - loss: 0.4675 - accuracy: 0.7757
# Epoch 52/100
# 30829/30829 - 1s - loss: 0.4669 - accuracy: 0.7768
# Epoch 53/100
# 30829/30829 - 1s - loss: 0.4666 - accuracy: 0.7768
# Epoch 54/100
# 30829/30829 - 1s - loss: 0.4662 - accuracy: 0.7769
# Epoch 55/100
# 30829/30829 - 1s - loss: 0.4658 - accuracy: 0.7753
# Epoch 56/100
# 30829/30829 - 1s - loss: 0.4658 - accuracy: 0.7776
# Epoch 57/100
# 30829/30829 - 1s - loss: 0.4659 - accuracy: 0.7763
# Epoch 58/100
# 30829/30829 - 1s - loss: 0.4657 - accuracy: 0.7775
# Epoch 59/100
# 30829/30829 - 1s - loss: 0.4644 - accuracy: 0.7776
# Epoch 60/100
# 30829/30829 - 1s - loss: 0.4658 - accuracy: 0.7781
# Epoch 61/100
# 30829/30829 - 1s - loss: 0.4641 - accuracy: 0.7769
# Epoch 62/100
# 30829/30829 - 1s - loss: 0.4648 - accuracy: 0.7760
# Epoch 63/100
# 30829/30829 - 1s - loss: 0.4639 - accuracy: 0.7777
# Epoch 64/100
# 30829/30829 - 1s - loss: 0.4636 - accuracy: 0.7771
# Epoch 65/100
# 30829/30829 - 1s - loss: 0.4634 - accuracy: 0.7782
# Epoch 66/100
# 30829/30829 - 1s - loss: 0.4638 - accuracy: 0.7780
# Epoch 67/100
# 30829/30829 - 1s - loss: 0.4632 - accuracy: 0.7809
# Epoch 68/100
# 30829/30829 - 1s - loss: 0.4624 - accuracy: 0.7788
# Epoch 69/100
# 30829/30829 - 1s - loss: 0.4634 - accuracy: 0.7796
# Epoch 70/100
# 30829/30829 - 1s - loss: 0.4627 - accuracy: 0.7779
# Epoch 71/100
# 30829/30829 - 1s - loss: 0.4625 - accuracy: 0.7790
# Epoch 72/100
# 30829/30829 - 1s - loss: 0.4621 - accuracy: 0.7798
# Epoch 73/100
# 30829/30829 - 1s - loss: 0.4618 - accuracy: 0.7793
# Epoch 74/100
# 30829/30829 - 1s - loss: 0.4614 - accuracy: 0.7803
# Epoch 75/100
# 30829/30829 - 1s - loss: 0.4611 - accuracy: 0.7785
# Epoch 76/100
# 30829/30829 - 1s - loss: 0.4613 - accuracy: 0.7798
# Epoch 77/100
# 30829/30829 - 1s - loss: 0.4606 - accuracy: 0.7799
# Epoch 78/100
# 30829/30829 - 1s - loss: 0.4602 - accuracy: 0.7797
# Epoch 79/100
# 30829/30829 - 1s - loss: 0.4608 - accuracy: 0.7801
# Epoch 80/100
# 30829/30829 - 1s - loss: 0.4606 - accuracy: 0.7791
# Epoch 81/100
# 30829/30829 - 1s - loss: 0.4607 - accuracy: 0.7812
# Epoch 82/100
# 30829/30829 - 1s - loss: 0.4601 - accuracy: 0.7801
# Epoch 83/100
# 30829/30829 - 1s - loss: 0.4599 - accuracy: 0.7806
# Epoch 84/100
# 30829/30829 - 1s - loss: 0.4597 - accuracy: 0.7798
# Epoch 85/100
# 30829/30829 - 1s - loss: 0.4605 - accuracy: 0.7811
# Epoch 86/100
# 30829/30829 - 1s - loss: 0.4600 - accuracy: 0.7811
# Epoch 87/100
# 30829/30829 - 1s - loss: 0.4590 - accuracy: 0.7823
# Epoch 88/100
# 30829/30829 - 1s - loss: 0.4597 - accuracy: 0.7805
# Epoch 89/100
# 30829/30829 - 1s - loss: 0.4586 - accuracy: 0.7806
# Epoch 90/100
# 30829/30829 - 1s - loss: 0.4588 - accuracy: 0.7811
# Epoch 91/100
# 30829/30829 - 1s - loss: 0.4587 - accuracy: 0.7806
# Epoch 92/100
# 30829/30829 - 1s - loss: 0.4585 - accuracy: 0.7821
# Epoch 93/100
# 30829/30829 - 1s - loss: 0.4576 - accuracy: 0.7810
# Epoch 94/100
# 30829/30829 - 1s - loss: 0.4586 - accuracy: 0.7804
# Epoch 95/100
# 30829/30829 - 1s - loss: 0.4574 - accuracy: 0.7825
# Epoch 96/100
# 30829/30829 - 1s - loss: 0.4575 - accuracy: 0.7814
# Epoch 97/100
# 30829/30829 - 1s - loss: 0.4575 - accuracy: 0.7814
# Epoch 98/100
# 30829/30829 - 1s - loss: 0.4579 - accuracy: 0.7810
# Epoch 99/100
# 30829/30829 - 1s - loss: 0.4570 - accuracy: 0.7820
# Epoch 100/100
# 30829/30829 - 1s - loss: 0.4565 - accuracy: 0.7826

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 10277/10277 - 0s - loss: 0.4720 - accuracy: 0.7775
# Normal Neural Network - Loss: 0.4720047159285191, Accuracy: 0.7774642109870911

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:10])

# %%
print(f"Predicted models: {encoded_predictions}")
print(f"Actual Labels: {list(y_test[:10])}")
# Out:
# Predicted models: [0 1 1 0 1 0 1 1 1 0]
# Actual Labels: [0, 0, 0, 0, 1, 0, 1, 0, 1, 1]

# %%
correlation=data.corr().unstack().sort_values(ascending=False).drop_duplicates()
correlation[:10]
# Out:
# decade        decade          1.000000
# duration_ms   sections        0.888952
# energy        loudness        0.772628
# danceability  valence         0.553858
# target        danceability    0.346097
# energy        valence         0.341427
# loudness      decade          0.329926
# energy        decade          0.324340
# loudness      target          0.286034
# danceability  loudness        0.274160
# dtype: float64

# %%
model.save("model_trained_2010s_13_feat.h5")

# %%
from pickle import dump
dump(X_scaler, open('scaler.pkl', 'wb'))
