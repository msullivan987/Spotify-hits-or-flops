# %%
from numpy.random import seed
seed(1)

import numpy as np
import pandas as pd

# %%
import tensorflow
tensorflow.keras.__version__
# Out:
# '2.2.4-tf'

# %%
data = pd.read_csv('../datasets/spotify_data.csv')
data.head()
# Out:
#                       track             artist  \
# 0                 Lucky Man  Montgomery Gentry
# 1            On The Hotline       Pretty Ricky
# 2        Clouds Of Dementia         Candlemass
# 3  Heavy Metal, Raise Hell!      Zwartketterij
# 4           I Got A Feelin'   Billy Currington
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:4GiXBCUF7H6YfNQsnBRIzl         0.578   0.471    4    -7.270
# 1  spotify:track:1zyqZONW985Cs4osz9wlsu         0.704   0.854   10    -5.477
# 2  spotify:track:6cHZf7RbxXCKwEkgAZT4mY         0.162   0.836    9    -3.009
# 3  spotify:track:2IjBPp2vMeX7LggzRN3iSX         0.188   0.994    4    -3.745
# 4  spotify:track:1tF370eYXUcWwkIvaq3IGz         0.630   0.764    2    -4.353
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0289      0.368000           0.00000     0.159    0.532
# 1     0       0.1830      0.018500           0.00000     0.148    0.688
# 2     1       0.0473      0.000111           0.00457     0.174    0.300
# 3     1       0.1660      0.000007           0.07840     0.192    0.333
# 4     1       0.0275      0.363000           0.00000     0.125    0.631
#
#      tempo  duration_ms  time_signature  chorus_hit  sections  target  decade
# 0  133.061       196707               4    30.88059        13       1    2000
# 1   92.988       242587               4    41.51106        10       1    2000
# 2   86.964       338893               4    65.32887        13       0    2000
# 3  148.440       255667               4    58.59528         9       0    2000
# 4  112.098       193760               4    22.62384        10       1    2000

# %%
X = data.drop(['track', 'artist', 'uri', 'target'], axis=1)
y = data["target"]
print(X.shape, y.shape)
# Out:
# (41106, 16) (41106,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=1)

# %%
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Create model and add layers
model = Sequential()
model.add(Dense(units=10, activation='relu', input_dim=16))
model.add(Dense(units=10, activation='relu'))
model.add(Dense(units=2, activation='softmax'))

# %%
# Compile and fit the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 10)                170
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 22
# =================================================================
# Total params: 302
# Trainable params: 302
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(
    X_train_scaled,
    y_train,
    epochs=200,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 30829 samples
# Epoch 1/200
# 30829/30829 - 2s - loss: 0.5808 - accuracy: 0.6896
# Epoch 2/200
# 30829/30829 - 1s - loss: 0.5257 - accuracy: 0.7316
# Epoch 3/200
# 30829/30829 - 1s - loss: 0.5163 - accuracy: 0.7416
# Epoch 4/200
# 30829/30829 - 1s - loss: 0.5083 - accuracy: 0.7482
# Epoch 5/200
# 30829/30829 - 1s - loss: 0.5017 - accuracy: 0.7529
# Epoch 6/200
# 30829/30829 - 1s - loss: 0.4970 - accuracy: 0.7575
# Epoch 7/200
# 30829/30829 - 1s - loss: 0.4936 - accuracy: 0.7590
# Epoch 8/200
# 30829/30829 - 1s - loss: 0.4909 - accuracy: 0.7607
# Epoch 9/200
# 30829/30829 - 1s - loss: 0.4890 - accuracy: 0.7621
# Epoch 10/200
# 30829/30829 - 1s - loss: 0.4879 - accuracy: 0.7642
# Epoch 11/200
# 30829/30829 - 1s - loss: 0.4878 - accuracy: 0.7637
# Epoch 12/200
# 30829/30829 - 1s - loss: 0.4867 - accuracy: 0.7642
# Epoch 13/200
# 30829/30829 - 1s - loss: 0.4859 - accuracy: 0.7642
# Epoch 14/200
# 30829/30829 - 1s - loss: 0.4854 - accuracy: 0.7637
# Epoch 15/200
# 30829/30829 - 1s - loss: 0.4843 - accuracy: 0.7650
# Epoch 16/200
# 30829/30829 - 1s - loss: 0.4828 - accuracy: 0.7683
# Epoch 17/200
# 30829/30829 - 1s - loss: 0.4816 - accuracy: 0.7671
# Epoch 18/200
# 30829/30829 - 1s - loss: 0.4813 - accuracy: 0.7674
# Epoch 19/200
# 30829/30829 - 2s - loss: 0.4802 - accuracy: 0.7689
# Epoch 20/200
# 30829/30829 - 1s - loss: 0.4799 - accuracy: 0.7685
# Epoch 21/200
# 30829/30829 - 1s - loss: 0.4797 - accuracy: 0.7695
# Epoch 22/200
# 30829/30829 - 1s - loss: 0.4786 - accuracy: 0.7705
# Epoch 23/200
# 30829/30829 - 2s - loss: 0.4777 - accuracy: 0.7711
# Epoch 24/200
# 30829/30829 - 1s - loss: 0.4771 - accuracy: 0.7716
# Epoch 25/200
# 30829/30829 - 1s - loss: 0.4774 - accuracy: 0.7703
# Epoch 26/200
# 30829/30829 - 1s - loss: 0.4773 - accuracy: 0.7708
# Epoch 27/200
# 30829/30829 - 1s - loss: 0.4762 - accuracy: 0.7708
# Epoch 28/200
# 30829/30829 - 2s - loss: 0.4757 - accuracy: 0.7723
# Epoch 29/200
# 30829/30829 - 1s - loss: 0.4754 - accuracy: 0.7717
# Epoch 30/200
# 30829/30829 - 1s - loss: 0.4752 - accuracy: 0.7719
# Epoch 31/200
# 30829/30829 - 1s - loss: 0.4753 - accuracy: 0.7717
# Epoch 32/200
# 30829/30829 - 1s - loss: 0.4747 - accuracy: 0.7719
# Epoch 33/200
# 30829/30829 - 2s - loss: 0.4739 - accuracy: 0.7722
# Epoch 34/200
# 30829/30829 - 1s - loss: 0.4745 - accuracy: 0.7697
# Epoch 35/200
# 30829/30829 - 1s - loss: 0.4740 - accuracy: 0.7720
# Epoch 36/200
# 30829/30829 - 1s - loss: 0.4734 - accuracy: 0.7714
# Epoch 37/200
# 30829/30829 - 1s - loss: 0.4725 - accuracy: 0.7726
# Epoch 38/200
# 30829/30829 - 2s - loss: 0.4728 - accuracy: 0.7731
# Epoch 39/200
# 30829/30829 - 1s - loss: 0.4728 - accuracy: 0.7731
# Epoch 40/200
# 30829/30829 - 1s - loss: 0.4714 - accuracy: 0.7747
# Epoch 41/200
# 30829/30829 - 2s - loss: 0.4719 - accuracy: 0.7736
# Epoch 42/200
# 30829/30829 - 2s - loss: 0.4711 - accuracy: 0.7738
# Epoch 43/200
# 30829/30829 - 1s - loss: 0.4707 - accuracy: 0.7724
# Epoch 44/200
# 30829/30829 - 1s - loss: 0.4715 - accuracy: 0.7755
# Epoch 45/200
# 30829/30829 - 2s - loss: 0.4711 - accuracy: 0.7740
# Epoch 46/200
# 30829/30829 - 1s - loss: 0.4706 - accuracy: 0.7735
# Epoch 47/200
# 30829/30829 - 1s - loss: 0.4702 - accuracy: 0.7740
# Epoch 48/200
# 30829/30829 - 1s - loss: 0.4703 - accuracy: 0.7747
# Epoch 49/200
# 30829/30829 - 1s - loss: 0.4702 - accuracy: 0.7754
# Epoch 50/200
# 30829/30829 - 2s - loss: 0.4701 - accuracy: 0.7748
# Epoch 51/200
# 30829/30829 - 1s - loss: 0.4685 - accuracy: 0.7749
# Epoch 52/200
# 30829/30829 - 1s - loss: 0.4689 - accuracy: 0.7749
# Epoch 53/200
# 30829/30829 - 1s - loss: 0.4693 - accuracy: 0.7748
# Epoch 54/200
# 30829/30829 - 1s - loss: 0.4682 - accuracy: 0.7756
# Epoch 55/200
# 30829/30829 - 1s - loss: 0.4688 - accuracy: 0.7760
# Epoch 56/200
# 30829/30829 - 2s - loss: 0.4681 - accuracy: 0.7753
# Epoch 57/200
# 30829/30829 - 1s - loss: 0.4677 - accuracy: 0.7752
# Epoch 58/200
# 30829/30829 - 1s - loss: 0.4675 - accuracy: 0.7754
# Epoch 59/200
# 30829/30829 - 1s - loss: 0.4675 - accuracy: 0.7755
# Epoch 60/200
# 30829/30829 - 2s - loss: 0.4666 - accuracy: 0.7765
# Epoch 61/200
# 30829/30829 - 1s - loss: 0.4671 - accuracy: 0.7758
# Epoch 62/200
# 30829/30829 - 1s - loss: 0.4666 - accuracy: 0.7764
# Epoch 63/200
# 30829/30829 - 1s - loss: 0.4657 - accuracy: 0.7773
# Epoch 64/200
# 30829/30829 - 1s - loss: 0.4662 - accuracy: 0.7757
# Epoch 65/200
# 30829/30829 - 2s - loss: 0.4660 - accuracy: 0.7779
# Epoch 66/200
# 30829/30829 - 1s - loss: 0.4656 - accuracy: 0.7790
# Epoch 67/200
# 30829/30829 - 1s - loss: 0.4648 - accuracy: 0.7775
# Epoch 68/200
# 30829/30829 - 2s - loss: 0.4651 - accuracy: 0.7777
# Epoch 69/200
# 30829/30829 - 2s - loss: 0.4642 - accuracy: 0.7774
# Epoch 70/200
# 30829/30829 - 1s - loss: 0.4643 - accuracy: 0.7788
# Epoch 71/200
# 30829/30829 - 1s - loss: 0.4633 - accuracy: 0.7803
# Epoch 72/200
# 30829/30829 - 1s - loss: 0.4632 - accuracy: 0.7792
# Epoch 73/200
# 30829/30829 - 2s - loss: 0.4625 - accuracy: 0.7779
# Epoch 74/200
# 30829/30829 - 1s - loss: 0.4622 - accuracy: 0.7797
# Epoch 75/200
# 30829/30829 - 1s - loss: 0.4621 - accuracy: 0.7794
# Epoch 76/200
# 30829/30829 - 1s - loss: 0.4619 - accuracy: 0.7797
# Epoch 77/200
# 30829/30829 - 2s - loss: 0.4617 - accuracy: 0.7803
# Epoch 78/200
# 30829/30829 - 1s - loss: 0.4616 - accuracy: 0.7792
# Epoch 79/200
# 30829/30829 - 1s - loss: 0.4608 - accuracy: 0.7808
# Epoch 80/200
# 30829/30829 - 2s - loss: 0.4610 - accuracy: 0.7810
# Epoch 81/200
# 30829/30829 - 1s - loss: 0.4606 - accuracy: 0.7796
# Epoch 82/200
# 30829/30829 - 1s - loss: 0.4600 - accuracy: 0.7806
# Epoch 83/200
# 30829/30829 - 1s - loss: 0.4602 - accuracy: 0.7811
# Epoch 84/200
# 30829/30829 - 1s - loss: 0.4594 - accuracy: 0.7814
# Epoch 85/200
# 30829/30829 - 2s - loss: 0.4594 - accuracy: 0.7813
# Epoch 86/200
# 30829/30829 - 1s - loss: 0.4590 - accuracy: 0.7826
# Epoch 87/200
# 30829/30829 - 1s - loss: 0.4587 - accuracy: 0.7826
# Epoch 88/200
# 30829/30829 - 1s - loss: 0.4583 - accuracy: 0.7807
# Epoch 89/200
# 30829/30829 - 2s - loss: 0.4586 - accuracy: 0.7813
# Epoch 90/200
# 30829/30829 - 1s - loss: 0.4578 - accuracy: 0.7814
# Epoch 91/200
# 30829/30829 - 1s - loss: 0.4578 - accuracy: 0.7833
# Epoch 92/200
# 30829/30829 - 1s - loss: 0.4578 - accuracy: 0.7817
# Epoch 93/200
# 30829/30829 - 2s - loss: 0.4574 - accuracy: 0.7832
# Epoch 94/200
# 30829/30829 - 1s - loss: 0.4579 - accuracy: 0.7834
# Epoch 95/200
# 30829/30829 - 1s - loss: 0.4573 - accuracy: 0.7835
# Epoch 96/200
# 30829/30829 - 1s - loss: 0.4569 - accuracy: 0.7813
# Epoch 97/200
# 30829/30829 - 1s - loss: 0.4562 - accuracy: 0.7841
# Epoch 98/200
# 30829/30829 - 2s - loss: 0.4567 - accuracy: 0.7825
# Epoch 99/200
# 30829/30829 - 2s - loss: 0.4563 - accuracy: 0.7833
# Epoch 100/200
# 30829/30829 - 1s - loss: 0.4560 - accuracy: 0.7841
# Epoch 101/200
# 30829/30829 - 1s - loss: 0.4556 - accuracy: 0.7845
# Epoch 102/200
# 30829/30829 - 1s - loss: 0.4550 - accuracy: 0.7837
# Epoch 103/200
# 30829/30829 - 2s - loss: 0.4553 - accuracy: 0.7844
# Epoch 104/200
# 30829/30829 - 1s - loss: 0.4548 - accuracy: 0.7843
# Epoch 105/200
# 30829/30829 - 1s - loss: 0.4542 - accuracy: 0.7854
# Epoch 106/200
# 30829/30829 - 1s - loss: 0.4542 - accuracy: 0.7851
# Epoch 107/200
# 30829/30829 - 1s - loss: 0.4539 - accuracy: 0.7859
# Epoch 108/200
# 30829/30829 - 2s - loss: 0.4541 - accuracy: 0.7843
# Epoch 109/200
# 30829/30829 - 1s - loss: 0.4544 - accuracy: 0.7866
# Epoch 110/200
# 30829/30829 - 1s - loss: 0.4531 - accuracy: 0.7849
# Epoch 111/200
# 30829/30829 - 2s - loss: 0.4533 - accuracy: 0.7873
# Epoch 112/200
# 30829/30829 - 1s - loss: 0.4528 - accuracy: 0.7867
# Epoch 113/200
# 30829/30829 - 1s - loss: 0.4519 - accuracy: 0.7876
# Epoch 114/200
# 30829/30829 - 1s - loss: 0.4523 - accuracy: 0.7866
# Epoch 115/200
# 30829/30829 - 2s - loss: 0.4514 - accuracy: 0.7878
# Epoch 116/200
# 30829/30829 - 1s - loss: 0.4509 - accuracy: 0.7867
# Epoch 117/200
# 30829/30829 - 1s - loss: 0.4508 - accuracy: 0.7870
# Epoch 118/200
# 30829/30829 - 1s - loss: 0.4504 - accuracy: 0.7879
# Epoch 119/200
# 30829/30829 - 2s - loss: 0.4495 - accuracy: 0.7878
# Epoch 120/200
# 30829/30829 - 2s - loss: 0.4499 - accuracy: 0.7876
# Epoch 121/200
# 30829/30829 - 1s - loss: 0.4499 - accuracy: 0.7884
# Epoch 122/200
# 30829/30829 - 1s - loss: 0.4486 - accuracy: 0.7883
# Epoch 123/200
# 30829/30829 - 2s - loss: 0.4480 - accuracy: 0.7894
# Epoch 124/200
# 30829/30829 - 1s - loss: 0.4480 - accuracy: 0.7890
# Epoch 125/200
# 30829/30829 - 1s - loss: 0.4477 - accuracy: 0.7895
# Epoch 126/200
# 30829/30829 - 1s - loss: 0.4465 - accuracy: 0.7899
# Epoch 127/200
# 30829/30829 - 1s - loss: 0.4471 - accuracy: 0.7907
# Epoch 128/200
# 30829/30829 - 2s - loss: 0.4460 - accuracy: 0.7905
# Epoch 129/200
# 30829/30829 - 1s - loss: 0.4459 - accuracy: 0.7915
# Epoch 130/200
# 30829/30829 - 1s - loss: 0.4450 - accuracy: 0.7921
# Epoch 131/200
# 30829/30829 - 2s - loss: 0.4449 - accuracy: 0.7916
# Epoch 132/200
# 30829/30829 - 1s - loss: 0.4447 - accuracy: 0.7919
# Epoch 133/200
# 30829/30829 - 1s - loss: 0.4448 - accuracy: 0.7928
# Epoch 134/200
# 30829/30829 - 1s - loss: 0.4442 - accuracy: 0.7931
# Epoch 135/200
# 30829/30829 - 2s - loss: 0.4436 - accuracy: 0.7919
# Epoch 136/200
# 30829/30829 - 2s - loss: 0.4439 - accuracy: 0.7924
# Epoch 137/200
# 30829/30829 - 1s - loss: 0.4436 - accuracy: 0.7933
# Epoch 138/200
# 30829/30829 - 1s - loss: 0.4429 - accuracy: 0.7934
# Epoch 139/200
# 30829/30829 - 2s - loss: 0.4430 - accuracy: 0.7938
# Epoch 140/200
# 30829/30829 - 1s - loss: 0.4428 - accuracy: 0.7925
# Epoch 141/200
# 30829/30829 - 1s - loss: 0.4429 - accuracy: 0.7927
# Epoch 142/200
# 30829/30829 - 1s - loss: 0.4429 - accuracy: 0.7936
# Epoch 143/200
# 30829/30829 - 2s - loss: 0.4417 - accuracy: 0.7933
# Epoch 144/200
# 30829/30829 - 1s - loss: 0.4422 - accuracy: 0.7926
# Epoch 145/200
# 30829/30829 - 1s - loss: 0.4416 - accuracy: 0.7944
# Epoch 146/200
# 30829/30829 - 1s - loss: 0.4418 - accuracy: 0.7932
# Epoch 147/200
# 30829/30829 - 2s - loss: 0.4418 - accuracy: 0.7941
# Epoch 148/200
# 30829/30829 - 1s - loss: 0.4408 - accuracy: 0.7949
# Epoch 149/200
# 30829/30829 - 1s - loss: 0.4409 - accuracy: 0.7936
# Epoch 150/200
# 30829/30829 - 1s - loss: 0.4410 - accuracy: 0.7928
# Epoch 151/200
# 30829/30829 - 2s - loss: 0.4407 - accuracy: 0.7938
# Epoch 152/200
# 30829/30829 - 1s - loss: 0.4400 - accuracy: 0.7943
# Epoch 153/200
# 30829/30829 - 1s - loss: 0.4402 - accuracy: 0.7949
# Epoch 154/200
# 30829/30829 - 1s - loss: 0.4400 - accuracy: 0.7968
# Epoch 155/200
# 30829/30829 - 1s - loss: 0.4405 - accuracy: 0.7946
# Epoch 156/200
# 30829/30829 - 1s - loss: 0.4400 - accuracy: 0.7944
# Epoch 157/200
# 30829/30829 - 2s - loss: 0.4395 - accuracy: 0.7939
# Epoch 158/200
# 30829/30829 - 1s - loss: 0.4395 - accuracy: 0.7952
# Epoch 159/200
# 30829/30829 - 1s - loss: 0.4399 - accuracy: 0.7939
# Epoch 160/200
# 30829/30829 - 1s - loss: 0.4395 - accuracy: 0.7943
# Epoch 161/200
# 30829/30829 - 1s - loss: 0.4391 - accuracy: 0.7962
# Epoch 162/200
# 30829/30829 - 1s - loss: 0.4390 - accuracy: 0.7956
# Epoch 163/200
# 30829/30829 - 2s - loss: 0.4388 - accuracy: 0.7967
# Epoch 164/200
# 30829/30829 - 1s - loss: 0.4394 - accuracy: 0.7952
# Epoch 165/200
# 30829/30829 - 1s - loss: 0.4387 - accuracy: 0.7955
# Epoch 166/200
# 30829/30829 - 2s - loss: 0.4387 - accuracy: 0.7961
# Epoch 167/200
# 30829/30829 - 1s - loss: 0.4385 - accuracy: 0.7965
# Epoch 168/200
# 30829/30829 - 1s - loss: 0.4385 - accuracy: 0.7954
# Epoch 169/200
# 30829/30829 - 1s - loss: 0.4378 - accuracy: 0.7970
# Epoch 170/200
# 30829/30829 - 1s - loss: 0.4380 - accuracy: 0.7963
# Epoch 171/200
# 30829/30829 - 2s - loss: 0.4386 - accuracy: 0.7955
# Epoch 172/200
# 30829/30829 - 1s - loss: 0.4380 - accuracy: 0.7966
# Epoch 173/200
# 30829/30829 - 1s - loss: 0.4382 - accuracy: 0.7963
# Epoch 174/200
# 30829/30829 - 1s - loss: 0.4379 - accuracy: 0.7948
# Epoch 175/200
# 30829/30829 - 2s - loss: 0.4381 - accuracy: 0.7949
# Epoch 176/200
# 30829/30829 - 1s - loss: 0.4372 - accuracy: 0.7955
# Epoch 177/200
# 30829/30829 - 1s - loss: 0.4378 - accuracy: 0.7970
# Epoch 178/200
# 30829/30829 - 1s - loss: 0.4376 - accuracy: 0.7958
# Epoch 179/200
# 30829/30829 - 1s - loss: 0.4373 - accuracy: 0.7964
# Epoch 180/200
# 30829/30829 - 2s - loss: 0.4381 - accuracy: 0.7964
# Epoch 181/200
# 30829/30829 - 1s - loss: 0.4368 - accuracy: 0.7947
# Epoch 182/200
# 30829/30829 - 1s - loss: 0.4377 - accuracy: 0.7968
# Epoch 183/200
# 30829/30829 - 1s - loss: 0.4373 - accuracy: 0.7970
# Epoch 184/200
# 30829/30829 - 2s - loss: 0.4372 - accuracy: 0.7966
# Epoch 185/200
# 30829/30829 - 2s - loss: 0.4368 - accuracy: 0.7969
# Epoch 186/200
# 30829/30829 - 1s - loss: 0.4370 - accuracy: 0.7954
# Epoch 187/200
# 30829/30829 - 1s - loss: 0.4370 - accuracy: 0.7968
# Epoch 188/200
# 30829/30829 - 1s - loss: 0.4364 - accuracy: 0.7976
# Epoch 189/200
# 30829/30829 - 2s - loss: 0.4365 - accuracy: 0.7972
# Epoch 190/200
# 30829/30829 - 1s - loss: 0.4362 - accuracy: 0.7973
# Epoch 191/200
# 30829/30829 - 1s - loss: 0.4363 - accuracy: 0.7957
# Epoch 192/200
# 30829/30829 - 1s - loss: 0.4364 - accuracy: 0.7969
# Epoch 193/200
# 30829/30829 - 2s - loss: 0.4365 - accuracy: 0.7963
# Epoch 194/200
# 30829/30829 - 1s - loss: 0.4368 - accuracy: 0.7966
# Epoch 195/200
# 30829/30829 - 1s - loss: 0.4365 - accuracy: 0.7968
# Epoch 196/200
# 30829/30829 - 1s - loss: 0.4360 - accuracy: 0.7975
# Epoch 197/200
# 30829/30829 - 2s - loss: 0.4362 - accuracy: 0.7960
# Epoch 198/200
# 30829/30829 - 1s - loss: 0.4361 - accuracy: 0.7965
# Epoch 199/200
# 30829/30829 - 1s - loss: 0.4349 - accuracy: 0.7982
# Epoch 200/200
# 30829/30829 - 2s - loss: 0.4356 - accuracy: 0.7987

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 10277/10277 - 0s - loss: 0.4449 - accuracy: 0.7931
# Normal Neural Network - Loss: 0.4448782949668257, Accuracy: 0.7931302785873413

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:10])

# %%
print(f"Predicted models: {encoded_predictions}")
print(f"Actual Labels: {list(y_test[:10])}")
# Out:
# Predicted models: [0 1 1 1 1 0 1 1 1 0]
# Actual Labels: [0, 0, 0, 0, 1, 0, 1, 0, 1, 1]

# %%
correlation=data.corr().unstack().sort_values(ascending=False).drop_duplicates()
correlation[:10]
# Out:
# decade        decade          1.000000
# duration_ms   sections        0.888952
# energy        loudness        0.772628
# danceability  valence         0.553858
# target        danceability    0.346097
# energy        valence         0.341427
# loudness      decade          0.329926
# energy        decade          0.324340
# loudness      target          0.286034
# danceability  loudness        0.274160
# dtype: float64

# %%
model.save("voice_model_trained.h5")
