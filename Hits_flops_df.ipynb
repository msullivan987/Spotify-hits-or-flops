# %%
import os
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
spot_url= "spotify-all/spotify_all.csv"
music_df=pd.read_csv(spot_url)
music_df.head()
# Out:
#                       track             artist  \
# 0                 Lucky Man  Montgomery Gentry
# 1            On The Hotline       Pretty Ricky
# 2        Clouds Of Dementia         Candlemass
# 3  Heavy Metal, Raise Hell!      Zwartketterij
# 4           I Got A Feelin'   Billy Currington
#
#                                     uri  danceability  energy   key  loudness  \
# 0  spotify:track:4GiXBCUF7H6YfNQsnBRIzl         0.578   0.471   4.0    -7.270
# 1  spotify:track:1zyqZONW985Cs4osz9wlsu         0.704   0.854  10.0    -5.477
# 2  spotify:track:6cHZf7RbxXCKwEkgAZT4mY         0.162   0.836   9.0    -3.009
# 3  spotify:track:2IjBPp2vMeX7LggzRN3iSX         0.188   0.994   4.0    -3.745
# 4  spotify:track:1tF370eYXUcWwkIvaq3IGz         0.630   0.764   2.0    -4.353
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0   1.0       0.0289      0.368000           0.00000     0.159    0.532
# ...

# %%
# Remove the rows with missing data
clean_music_df = music_df.dropna(how="any")
clean_music_df.count()
# Out:
# track               41106
# artist              41106
# uri                 41106
# danceability        41106
# energy              41106
# key                 41106
# loudness            41106
# mode                41106
# speechiness         41106
# acousticness        41106
# instrumentalness    41106
# liveness            41106
# valence             41106
# tempo               41106
# duration_ms         41106
# time_signature      41106
# chorus_hit          41106
# sections            41106
# target              41106
# decade              41106
# dtype: int64

# %%
clean_music_df["target"].value_counts()
# Out:
# 0.0    20553
# 1.0    20553
# Name: target, dtype: int64

# %%
# show clean music dataFrame

# %%
clean_music_df.head()
# Out:
#                       track             artist  \
# 0                 Lucky Man  Montgomery Gentry
# 1            On The Hotline       Pretty Ricky
# 2        Clouds Of Dementia         Candlemass
# 3  Heavy Metal, Raise Hell!      Zwartketterij
# 4           I Got A Feelin'   Billy Currington
#
#                                     uri  danceability  energy   key  loudness  \
# 0  spotify:track:4GiXBCUF7H6YfNQsnBRIzl         0.578   0.471   4.0    -7.270
# 1  spotify:track:1zyqZONW985Cs4osz9wlsu         0.704   0.854  10.0    -5.477
# 2  spotify:track:6cHZf7RbxXCKwEkgAZT4mY         0.162   0.836   9.0    -3.009
# 3  spotify:track:2IjBPp2vMeX7LggzRN3iSX         0.188   0.994   4.0    -3.745
# 4  spotify:track:1tF370eYXUcWwkIvaq3IGz         0.630   0.764   2.0    -4.353
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0   1.0       0.0289      0.368000           0.00000     0.159    0.532
# ...

# %%
#
